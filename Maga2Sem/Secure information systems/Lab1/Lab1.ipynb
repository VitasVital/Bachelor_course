# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Iris

# %%
data = pd.read_csv('Iris.csv')
data
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# 0      1            5.1           3.5            1.4           0.2  \
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
data = data.drop(['Id', 'Species'], axis=1).values
data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
sepal_length=[]
sepal_width=[]
petal_length=[]
petal_width=[]
for dot in data:
	sepal_length.append(dot[0])
	sepal_width.append(dot[1])
	petal_length.append(dot[2])
	petal_width.append(dot[3])
plt.figure(1)
setosa,=plt.plot(sepal_length[:50], sepal_width[:50], 'ro', label='Setosa')
versicolor,= plt.plot(sepal_length[50:100], sepal_width[50:100], 'g^', label='Versicolor')
virginica,= plt.plot(sepal_length[100:150], sepal_width[100:150], 'bs', label='Verginica')
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)
plt.xlabel('Selal Length')
plt.ylabel('Selal Width')
plt.show()

# %% [markdown]
# # Suicide Rates Overview 1985 to 2016
# https://www.kaggle.com/datasets/russellyates88/suicide-rates-overview-1985-to-2016

# %%
data1 = pd.read_csv('SuicideRatesOverview.csv')[:960].drop(['country', 'age', 'sex', 'country-year', 'HDI for year', 'generation'], axis=1)
#data1['country'].value_counts()
data1
# Out:
#      year  suicides_no  population  suicides/100k pop  gdp_for_year ($)
# 0    1987           21      312900               6.71      2,156,624,900  \
# 1    1987           16      308000               5.19      2,156,624,900
# 2    1987           14      289700               4.83      2,156,624,900
# 3    1987            1       21800               4.59      2,156,624,900
# 4    1987            9      274300               3.28      2,156,624,900
# ..    ...          ...         ...                ...                ...
# 955  2015          114     3235582               3.52    594,749,285,413
# 956  2015          166     5301368               3.13    594,749,285,413
# 957  2015           27     1344980               2.01    594,749,285,413
# 958  2015           39     3672155               1.06    594,749,285,413
# 959  2015           19     3549219               0.54    594,749,285,413
#
#      gdp_per_capita ($)
# 0                   796
# 1                   796
# ...

# %%
data1 = data1.values
data1
# Out:
# array([[1987, 21, 312900, 6.71, '2,156,624,900', 796],
#        [1987, 16, 308000, 5.19, '2,156,624,900', 796],
#        [1987, 14, 289700, 4.83, '2,156,624,900', 796],
#        ...,
#        [2015, 27, 1344980, 2.01, '594,749,285,413', 14981],
#        [2015, 39, 3672155, 1.06, '594,749,285,413', 14981],
#        [2015, 19, 3549219, 0.54, '594,749,285,413', 14981]], dtype=object)

# %%
population=[]
suicides_100k_pop=[]
for dot in data1:
	population.append(dot[2])
	suicides_100k_pop.append(dot[3])
plt.figure(1)
Albania,=plt.plot(population[:264], suicides_100k_pop[:264], 'ro', label='Albania')
Antigua_and_Barbuda,= plt.plot(population[264:264+324], suicides_100k_pop[264:264+324], 'g^', label='Antigua_and_Barbuda')
Argentina,= plt.plot(population[264+324:264+324+372], suicides_100k_pop[264+324:264+324+372], 'bs', label='Argentina')
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)
plt.xlabel('Population')
plt.ylabel('Suicides/100k pop')
plt.show()

# %% [markdown]
# # Gender Recognition by Voice
# https://www.kaggle.com/datasets/primaryobjects/voicegender

# %%
data2 = pd.read_csv('voice.csv').drop(['label'], axis=1)
# data2['label'].value_counts() # 1584
data2
# Out:
#       meanfreq        sd    median       Q25       Q75       IQR       skew
# 0     0.059781  0.064241  0.032027  0.015071  0.090193  0.075122  12.863462  \
# 1     0.066009  0.067310  0.040229  0.019414  0.092666  0.073252  22.423285
# 2     0.077316  0.083829  0.036718  0.008701  0.131908  0.123207  30.757155
# 3     0.151228  0.072111  0.158011  0.096582  0.207955  0.111374   1.232831
# 4     0.135120  0.079146  0.124656  0.078720  0.206045  0.127325   1.101174
# ...        ...       ...       ...       ...       ...       ...        ...
# 3163  0.131884  0.084734  0.153707  0.049285  0.201144  0.151859   1.762129
# 3164  0.116221  0.089221  0.076758  0.042718  0.204911  0.162193   0.693730
# 3165  0.142056  0.095798  0.183731  0.033424  0.224360  0.190936   1.876502
# 3166  0.143659  0.090628  0.184976  0.043508  0.219943  0.176435   1.591065
# 3167  0.165509  0.092884  0.183044  0.070072  0.250827  0.180756   1.705029
#
# ...

# %%
data2 = data2.values
data2
# Out:
# array([[0.05978098, 0.06424127, 0.03202691, ..., 0.0078125 , 0.        ,
#         0.        ],
#        [0.06600874, 0.06731003, 0.04022873, ..., 0.0546875 , 0.046875  ,
#         0.05263158],
#        [0.0773155 , 0.08382942, 0.03671846, ..., 0.015625  , 0.0078125 ,
#         0.04651163],
#        ...,
#        [0.14205626, 0.09579843, 0.18373124, ..., 2.9375    , 2.9296875 ,
#         0.19475862],
#        [0.14365874, 0.09062826, 0.18497617, ..., 3.59375   , 3.5859375 ,
#         0.31100218],
#        [0.16550895, 0.09288354, 0.18304392, ..., 0.5546875 , 0.546875  ,
#         0.35      ]])

# %%
Q25=[]
IQR=[]
for dot in data2:
	Q25.append(dot[3])
	IQR.append(dot[5])
plt.figure(1)
male,=plt.plot(Q25[:1584], IQR[:1584], 'ro', label='Male')
female,= plt.plot(Q25[1584:1584 * 2], IQR[1584:1584 * 2], 'g^', label='Female')
plt.legend(bbox_to_anchor=(1.05,1), loc=2, borderaxespad=0.)
plt.xlabel('Первый квартиль (в кГц)')
plt.ylabel('Межквартильный диапазон (в кГц)')
plt.show()

# %% [markdown]
# # Student Alcohol Consumption
# https://www.kaggle.com/datasets/uciml/student-alcohol-consumption

# %%
data3 = pd.read_csv('student-mat.csv').sort_values(by=['sex']) #.drop(['label'], axis=1)
data3 #['sex'].value_counts() # 1584
# data3

# F    208
# M    187
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher  \
# 319     GP   F   18       U     GT3       T     4     4   teacher     other
# 318     GP   F   17       R     GT3       T     3     4   at_home  services
# 152     GP   F   15       R     GT3       T     3     3  services  services
# 317     GP   F   18       U     GT3       T     4     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 170     GP   M   16       U     GT3       T     3     4     other     other
# 166     GP   M   16       U     GT3       T     2     2     other     other
# 165     GP   M   16       U     GT3       T     3     2  services  services
# 177     GP   M   17       U     GT3       T     3     3     other     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %%
data3 = data3.values
data3
